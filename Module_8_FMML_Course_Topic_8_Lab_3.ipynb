# %% [markdown]
# <a href="https://colab.research.google.com/github/VigneshPathivada443/FMML-COURSE-ASSIGNMENTS/blob/main/Module_8_FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-04 18:03:05--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  66.0MB/s    in 1.0s
#
# 2023-05-04 18:03:10 (66.0 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2415 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 10615  1604.02123v1  This work is motivated by the needs of predict...  stat
# 6408   1701.04516v1  One-Class Classification (OCC) has been prime ...    cs
# 27194  1702.07371v1  Nowadays actions are increasingly being handle...    cs
# 28758  1707.06833v1  Text recognition in scene image and video fram...    cs
# 29574  1709.08164v1  In this work, we present tensor-based linear a...    cs
# ...             ...                                                ...   ...
# 22828  1708.00122v1  Disease classification is a crucial element of...  stat
# 24704   1410.7922v1  This paper presents a novel extended dynamic p...    cs
# 6654   1704.08265v1  In the context of variable selection, ensemble...  stat
# 13051   1312.7001v1  A new approach for feature extraction from tim...  stat
# 25327  1507.07075v1  Mathematical morphology (MM) helps to describe...    cs
#
#                                                    title  year  \
# 10615  Multilevel Weighted Support Vector Machine for...  2016
# 6408   On The Construction of Extreme Learning Machin...  2017
# 27194  Feasibility of Principal Component Analysis in...  2017
# 28758  Date-Field Retrieval in Scene Image and Video ...  2017
# 29574  Tensor-Based Classifiers for Hyperspectral Dat...  2017
# ...                                                  ...   ...
# 22828  Application of Support Vector Machine Modeling...  2017
# 24704  Extended Dynamic Programming and Fast Multidim...  2014
# 6654                Pruning variable selection ensembles  2017
# 13051  A regression model with a hidden logistic proc...  2013
# 25327  A Study of Morphological Filtering Using Graph...  2015
#
#                                                 keywords
# 10615  [motivated, predictive, analytics, healthcare,...
# 6408   [classification, researchers, effectively, dis...
# 27194  [increasingly, electronic, interaction, biomet...
# 28758  [recognition, difficult, resolution, backgroun...
# 29574  [nonlinear, hyperspectral, classification, exp...
# ...                                                  ...
# 22828  [classification, biomedical, demonstrated, tec...
# 24704  [programming, minimization, correspondence, si...
# 6654   [selection, increasing, potential, selection, ...
# 13051  [extraction, regression, incorporating, parame...
# 25327  [mathematical, morphology, effectively, morpho...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 10615    [motivated, predictive, analytics, healthcare,...
# 6408     [classification, researchers, effectively, dis...
# 27194    [increasingly, electronic, interaction, biomet...
# 28758    [recognition, difficult, resolution, backgroun...
# 29574    [nonlinear, hyperspectral, classification, exp...
#                                ...
# 13579    [artificial, optimization, algorithm, intellig...
# 1489     [quantities, cardinals, quantifiers, processes...
# 30961    [highlight, detection, summarizing, spatially,...
# 4315     [cognitive, performed, routinely, determining,...
# 35189    [reasoning, knowledge, knowledge, acquisition,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8912 words.
# Out of those 4597 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="60a8210f-9d43-4993-b96c-008e10d51373" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("60a8210f-9d43-4993-b96c-008e10d51373")) {                    Plotly.newPlot(                        "60a8210f-9d43-4993-b96c-008e10d51373",                        [{"x":["problematic","framework","imputation","regression","multilevel","invariably","performance","predictive","electronic","techniques","development","preprocessing","imbalanced","applications","simultaneously","algorithms","imbalance","motivated","healthcare","interests","analytics","specialized","sensitive","benchmark","maximization","represented","classification","disciplines","threshold","functionality","categories","classifiers","approaches","reconstruction","effectively","parameters","consuming","researchers","capability","compatible","iterative","sequential","remaining","effectiveness","construction","different","traditional","artificial","discipline","feasibility","dimensionality","recognizes","eigenvalues","recognise","identification","authentication","information","detection","similarity","processing","euclidean","recognition","calculating","interaction","efficient","implementation","increasingly","analyzing","biometrics","eigenvectors","principal","recognizer","recognize","associated","extracted","fingerprint","reduction","experimental","advantages","component","background","decomposition","backgrounds","segmenting","punctuations","resolution","constructed","experiment","including","enhancement","characters","alternative","difficult","retrieval","histogram","searching","conversion","architecture","capabilities","available","evaluated","introduce","feedforward","canonical","characterizing","architectures","especially","comparisons","outperformance","classifier","interpretation","regarding","respective","principles","hyperspectral","satisfies","nonlinear","exploiting","coefficients","modification","indicates","furthermore","appropriate","assumption","variables","addressed","distribution","typically","transductive","monitoring","structure","approximation","marginals","perspectives","functions","estimation","processes","gaussianity","likelihoods","prediction","dominated","dependence","capturing","computational","expressions","convenient","cumulative","pollution","analytical","computing","gaussians","optimisation","illustrated","procedure","clustering","embedding","eigenvalue","theoretical","embeddings","programming","distances","literature","dimensional","estimating","unsupervised","expansive","experiments","contraction","tensorflow","progressively","convolutional","empirical","respectively","contribution","nonlinearity","increasing","separation","continuous","properties","representation","reproducible","competitive","algorithm","perceptron","connection","reinforcement","classical","evaluation","comparison","alternatives","randomized","discovery","inherently","systematic","investigation","navigation","alternatively","exploitation","environment","explicitly"],"y":[10,547,6,126,3,2,895,63,22,386,130,14,8,432,115,612,9,78,10,12,16,25,70,196,35,92,484,9,38,13,70,117,446,104,126,240,33,80,50,13,73,87,14,214,60,758,185,147,5,21,48,4,5,6,93,7,666,337,139,273,28,362,13,78,413,139,68,67,5,8,36,3,41,100,115,7,114,370,80,100,73,69,5,18,2,101,48,84,259,24,30,95,145,115,18,32,7,258,51,289,151,325,15,15,16,132,123,32,3,167,59,31,28,45,15,13,61,71,32,29,28,178,78,73,132,45,214,126,7,44,334,109,3,16,210,190,112,1,4,239,6,27,32,277,43,13,12,2,26,135,10,19,22,118,135,97,5,148,66,124,35,112,187,54,133,2,636,1,7,10,358,158,84,70,4,102,37,100,204,334,4,125,859,13,33,128,85,275,143,23,31,41,18,32,30,37,7,21,121,85],"type":"bar"},{"x":["problematic","framework","imputation","regression","multilevel","inv ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4597,), (4597, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.795

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.4095238095238096);'>Detecting</span> <span style=''>Figures</span> <span style=''>and</span> <span style=''>Part</span> <span style=''>Labels</span> <span style=''>in</span> <span style=''>Patents</span> <span style='background-color:rgba(0, 255, 0, 0.3684210526315789);'>Competition</span> <span style=''>Based</span> <span style='background-color:rgba(0, 255, 0, 0.4207650273224043);'>Development</span> <span style=''>of</span> <span style=''>Image</span> <span style='background-color:rgba(0, 255, 0, 0.43684210526315786);'>Processing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithms</span> <br/><br/><span style=''>We</span> <span style=''>report</span> <span style=''>the</span> <span style=''>findings</span> <span style=''>of</span> <span style=''>a</span> <span style=''>month</span> <span style=''>long</span> <span style=''>online</span> <span style='background-color:rgba(0, 255, 0, 0.3684210526315789);'>competition</span> <span style=''>in</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.4782608695652174);'>participants</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>augmenting</span> <span style=''>the</span> <span style=''>digital</span> <span style=''>version</span> <span style=''>of</span> <span style=''>patent</span> <span style='background-color:rgba(0, 255, 0, 0.46153846153846145);'>documents</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>published</span> <span style=''>by</span> <span style=''>the</span> <span style=''>United</span> <span style=''>States</span> <span style=''>Patent</span> <span style=''>and</span> <span style=''>Trademark</span> <span style=''>Office</span> <span style=''>(USPTO)</span> <span style=''>The</span> <span style=''>goal</span> <span style=''>was</span> <span style=''>to</span> <span style=''>detect</span> <span style=''>figures</span> <span style=''>and</span> <span style=''>part</span> <span style=''>labels</span> <span style=''>in</span> <span style=''>US</span> <span style=''>patent</span> <span style=''>drawing</span> <span style=''>pages</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>challenge</span> <span style=''>drew</span> <span style=''>232</span> <span style=''>teams</span> <span style=''>of</span> <span style=''>two</span> <span style=''>of</span> <span style=''>which</span> <span style=''>70</span> <span style=''>teams</span> <span style=''>(30)</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>submitted</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>solutions</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714285);'>Collectively</span> <span style=''>teams</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>submitted</span> <span style=''>1797</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>solutions</span> <span style=''>that</span> <span style=''>were</span> <span style=''>compiled</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3684210526315789);'>competition</span> <span style=''>servers</span> <span style='background-color:rgba(0, 255, 0, 0.4782608695652174);'>Participants</span> <span style=''>reported</span> <span style=''>spending</span> <span style=''>an</span> <span style=''>average</span> <span style=''>of</span> <span style=''>63</span> <span style=''>hours</span> <span style='background-color:rgba(0, 255, 0, 0.3861386138613862);'>developing</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>solutions</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style=''>in</span> <span style=''>a</span> <span style=''>total</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Q</span> <span style=''>and</span> <span style=''>A</span> <span style=''>Learning</span> <span style=''>Methods</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimating</span> <span style=''>Optimal</span> <span style=''>Dynamic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Treatment</span> <span style=''>Regimes</span> <br/><br/><span style=''>In</span> <span style=''>clinical</span> <span style=''>practice</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>physicians</span> <span style=''>make</span> <span style=''>a</span> <span style=''>series</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatment</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decisions</span> <span style=''>over</span> <span style=''>the</span> <span style=''>course</span> <span style=''>of</span> <span style=''>a</span> <span style=''>patients</span> <span style=''>disease</span> <span style=''>based</span> <span style=''>on</span> <span style=''>hisher</span> <span style=''>baseline</span> <span style=''>and</span> <span style=''>evolving</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characteristics</span> <span style=''>A</span> <span style=''>dynamic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatment</span> <span style=''>regime</span> <span style=''>is</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequential</span> <span style=''>decision</span> <span style=''>rules</span> <span style=''>that</span> <span style=''>operationalizes</span> <span style=''>this</span> <span style=''>process</span> <span style=''>Each</span> <span style=''>rule</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corresponds</span> <span style=''>to</span> <span style=''>a</span> <span style=''>decision</span> <span style=''>point</span> <span style=''>and</span> <span style=''>dictates</span> <span style=''>the</span> <span style=''>next</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatment</span> <span style=''>action</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>accrued</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>Using</span> <span style=''>existing</span> <span style=''>data</span> <span style=''>a</span> <span style=''>key</span> <span style=''>goal</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>the</span> <span style=''>optimal</span> <span style=''>regime</span> <span style=''>that</span> <span style=''>if</span> <span style=''>followed</span> <span style=''>by</span> <span style=''>the</span> <span style=''>patient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>population</span> <span style=''>would</span> <span style=''>yield</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>favorable</span> <span style=''>outcome</span> <span style=''>on</span> <span style=''>average</span> <span style=''>Q</span> <span style=''>and</span> <span style=''>A</span> <span style=''>learning</span> <span style=''>are</span> <span style=''>two</span> <span style=''>main</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>for</span> <span style=''>this</span> <span style=''>purpose</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>detailed</span> <span style=''>account</span> <span style=''>of</span> <span style=''>these</span> <span style=''>methods</span> <span style=''>study</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>illustrate</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Sober</span> <span style=''>Look</span> <span style=''>at</span> <span style=''>Spectral</span> <span style=''>Learning</span> <br/><br/><span style=''>Spectral</span> <span style=''>learning</span> <span style=''>recently</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generated</span> <span style=''>lots</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>excitement</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>largely</span> <span style=''>because</span> <span style=''>it</span> <span style=''>is</span> <span style=''>the</span> <span style=''>first</span> <span style=''>known</span> <span style=''>method</span> <span style=''>to</span> <span style=''>produce</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimates</span> <span style=''>(under</span> <span style=''>suitable</span> <span style=''>conditions)</span> <span style=''>for</span> <span style=''>several</span> <span style=''>latent</span> <span style=''>variable</span> <span style=''>models</span> <span style=''>In</span> <span style=''>contrast</span> <span style=''>maximum</span> <span style='background-color:rgba(255, 0, 0, 0.5366795366795367);'>likelihood</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimates</span> <span style=''>may</span> <span style=''>get</span> <span style=''>trapped</span> <span style=''>in</span> <span style=''>local</span> <span style=''>optima</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>nature</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.5366795366795367);'>likelihood</span> <span style=''>function</span> <span style=''>of</span> <span style=''>latent</span> <span style=''>variable</span> <span style=''>models</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>do</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style='background-color:rgba(0, 255, 0, 0.44356955380577423);'>evaluation</span> <span style=''>of</span> <span style=''>spectral</span> <span style=''>learning</span> <span style=''>(SL)</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expectation</span> <span style='background-color:rgba(255, 0, 0, 0.306930693069307);'>maximization</span> <span style=''>(EM)</span> <span style=''>which</span> <span style=''>reveals</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>gap</span> <span style=''>between</span> <span style=''>the</span> <span style=''>theory</span> <span style=''>and</span> <span style=''>the</span> <span style=''>practice</span> <span style=''>First</span> <span style=''>SL</span> <span style=''>often</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>negative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilities</span> <span style=''>Second</span> <span style=''>EM</span> <span style=''>often</span> <span style=''>yields</span> <span style=''>better</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimates</span> <span style=''>than</span> <span style=''>spectral</span> <span style=''>learning</span> <span style=''>and</span> <span style=''>it</span> <span style=''>does</span> <span style=''>not</span> <span style=''>seem</span> <span style=''>to</span> <span style=''>get</span> <span style=''>stuck</span> <span style=''>in</span> <span style=''>local</span> <span style=''>optima</span> <span style=''>We</span> <span style=''>discuss</span> <span style=''>how</span> <span style=''>the</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style=''>Upper</span> <span style=''>Bound</span> <span style=''>on</span> <span style=''>Knots</span> <span style=''>in</span> <span style=''>Neural</span> <span style=''>Networks</span> <br/><br/><span style=''>Neural</span> <span style=''>networks</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>rectified</span> <span style=''>linear</span> <span style=''>unit</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>activations</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>essentially</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style=''>linear</span> <span style=''>splines</span> <span style=''>As</span> <span style=''>such</span> <span style=''>one</span> <span style=''>of</span> <span style=''>many</span> <span style=''>ways</span> <span style=''>to</span> <span style=''>measure</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expressivity</span> <span style=''>of</span> <span style=''>a</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>is</span> <span style=''>to</span> <span style=''>count</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>knots</span> <span style=''>in</span> <span style=''>the</span> <span style=''>spline</span> <span style=''>model</span> <span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>knots</span> <span style=''>in</span> <span style=''>fully</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connected</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>feedforward</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>rectified</span> <span style=''>linear</span> <span style=''>unit</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>activation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intentionally</span> <span style=''>keep</span> <span style=''>the</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>very</span> <span style=''>simple</span> <span style=''>so</span> <span style=''>as</span> <span style=''>to</span> <span style=''>make</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style=''>analyses</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approachable</span> <span style=''>An</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>induction</span> <span style=''>on</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>layers</span> <span style=''>l</span> <span style=''>reveals</span> <span style=''>a</span> <span style=''>tight</span> <span style=''>upper</span> <span style=''>bound</span> <span style=''>on</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>knots</span> <span style=''>in</span> <span style=''>mathbbR</span> <span style=''>to</span> <span style=''>mathbbRp</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>With</span> <span style=''>n</span> <span style=''>i</span> <span style=''>gg</span> <span style=''>1</span> <span style=''>neurons</span> <span style=''>in</span> <span style=''>layer</span> <span style=''>i</span> <span style=''>1</span> <span style=''>dots</span> <span style=''>l</span> <span style=''>the</span> <span style=''>upper</span> <span style=''>bound</span> <span style=''>is</span> <span style='background-colo ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.0962962962962963)
# 	experimental (0.13051146384479717)
# 	evaluation (0.09700176366843033)
# 	automatic (0.07583774250440917)
# 	segmentation (0.06666666666666667)
# 	architecture (0.091005291005291)
# 	detection (0.11887125220458554)
# 	different (0.2673721340388007)
# 	recognition (0.127689594356261)
# 	convolutional (0.12627865961199294)
#
# Some Statistics words are:
# 	stochastic (0.13282442748091602)
# 	distributions (0.12875318066157762)
# 	variables (0.14045801526717558)
# 	theoretical (0.15368956743002546)
# 	statistical (0.1623409669211196)
# 	estimation (0.17709923664122137)
# 	distribution (0.18931297709923664)
# 	dimensional (0.18473282442748093)
# 	inference (0.2035623409669211)
# 	regression (0.17404580152671756)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="5a84317b-242c-4baf-9e87-d2626e788a5a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a84317b-242c-4baf-9e87-d2626e788a5a")) {                    Plotly.newPlot(                        "5a84317b-242c-4baf-9e87-d2626e788a5a",                        [{"x":["problematic","framework","imputation","regression","multilevel","invariably","performance","predictive","electronic","techniques","development","preprocessing","imbalanced","applications","simultaneously","algorithms","imbalance","motivated","healthcare","interests","analytics","specialized","sensitive","benchmark","maximization","represented","classification","disciplines","threshold","functionality","categories","classifiers","approaches","reconstruction","effectively","parameters","consuming","researchers","capability","compatible","iterative","sequential","remaining","effectiveness","construction","different","traditional","artificial","discipline","feasibility","dimensionality","recognizes","eigenvalues","recognise","identification","authentication","information","detection","similarity","processing","euclidean","recognition","calculating","interaction","efficient","implementation","increasingly","analyzing","biometrics","eigenvectors","principal","recognizer","recognize","associated","extracted","fingerprint","reduction","experimental","advantages","component","background","decomposition","backgrounds","segmenting","punctuations","resolution","constructed","experiment","including","enhancement","characters","alternative","difficult","retrieval","histogram","searching","conversion","architecture","capabilities","available","evaluated","introduce","feedforward","canonical","characterizing","architectures","especially","comparisons","outperformance","classifier","interpretation","regarding","respective","principles","hyperspectral","satisfies","nonlinear","exploiting","coefficients","modification","indicates","furthermore","appropriate","assumption","variables","addressed","distribution","typically","transductive","monitoring","structure","approximation","marginals","perspectives","functions","estimation","processes","gaussianity","likelihoods","prediction","dominated","dependence","capturing","computational","expressions","convenient","cumulative","pollution","analytical","computing","gaussians","optimisation","illustrated","procedure","clustering","embedding","eigenvalue","theoretical","embeddings","programming","distances","literature","dimensional","estimating","unsupervised","expansive","experiments","contraction","tensorflow","progressively","convolutional","empirical","respectively","contribution","nonlinearity","increasing","separation","continuous","properties","representation","reproducible","competitive","algorithm","perceptron","connection","reinforcement","classical","evaluation","comparison","alternatives","randomized","discovery","inherently","systematic","investigation","navigation","alternatively","exploitation","environment","explicitly","successfully","classically","efficiently","approached","exploration","automatic","controlled","instructions","collaborative","knowledge","discussing","production","describing","extensions","dedicated","generation","depending","independent","restricted","correctly","attractive","heuristic","conditionally","temporarily","increases","conceptually","ancestral","selecting","distributions","retaining","guarantees","magnitude","algorithmic","selection","efficiency","similarly","preserving","applicable","significantly","reconsidered","faithfully","preferable","predictions","unification","desirable","particular","understanding","interpret","components","intuition","importance","interpreting","interpretability","consistency","differentia ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	pharmacokinetic
# 	correspondingly
# 	subdifferential
# 	spectroradiometer
# 	econometrics
# 	exemplifies
# 	timeseries
# 	composers
# 	recombines
# 	dissertation
# 	epigenomics
# 	transcriptional
# 	contingency
# 	triggering
# 	neuroscientists
# 	projectorg
# 	periodicity
# 	straggler
# 	oblivious
# 	straggling
# Some words which never appear in Statistics papers:
# 	recognise
# 	authentication
# 	recognizer
# 	punctuations
# 	classically
# 	temporarily
# 	reconsidered
# 	quantizer
# 	allocated
# 	traveling
# 	wheelchair
# 	imperfections
# 	pedestrian
# 	gazetteers
# 	mathematicians
# 	unimportant
# 	geographic
# 	manuscripts
# 	computerized
# 	experiences

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0351777096549007e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7233333333333334
